# %%
import sys, os

## Include previous level directories to the module import path
sys.path.insert(0, os.path.abspath(os.path.join("..")))

# import arviz as az
import numpy as np
import h5py

# Export the results to GetDist

# Notice loadMCSamples requires a *full path*
import os
from matplotlib import pyplot as plt
import matplotlib


matplotlib.rcParams.update(
    {
        "font.size": 16,
        "axes.labelsize": 24,
        "axes.titlesize": 18,
        "text.usetex": True,
        "xtick.major.width": 1.5,
        "xtick.minor.width": 1.2,
        "ytick.major.width": 1.5,
        "ytick.minor.width": 1.2,
        "legend.fontsize": 18,
    }
)

# Deep purples / indigos
c_flatirons = "#440154"
c_flatirons_l = "#472d7b"
c_flatirons_ll = "#3b528b"

# Teal / cyan region
c_sunshine = "#2a788e"
c_sunshine_l = "#21908d"
c_sunshine_ll = "#20a386"

# Green-cyan (maximum brightness allowed)
c_skyline = "#35b779"
c_skyline_l = "#5ec962"  # Cap brightness here
# c_skyline_ll = omitted due to low print contrast

# Blue highlight
c_midnight = "#31688e"

# %%
sys.path.insert(0, os.path.abspath(os.path.join("../../DLA_data")))

# %%
import dla_data

# %%
import os.path as path

datadir = os.path.abspath(os.path.join("../../DLA_data"))


def absorption_distance():
    """Compute X(z), the absorption distance per sightline (eq. 9 of Nagamine et al 2003)
    in dimensionless units."""
    # h * 100 km/s/Mpc in h/s
    h100 = 3.2407789e-18
    # in cm/s
    light = 2.9979e10
    # Internal gadget length unit: 1 kpc/h in cm/h
    UnitLength_in_cm = 3.085678e21
    redshift = 3
    box = 25000
    # Units: h/s   s/cm                        kpc/h      cm/kpc
    return h100 / light * (1 + redshift) ** 2 * box * UnitLength_in_cm


def altay_data(label="Altay 2011"):
    """Plot the simulation cddf from Altay 2011: 1012.4014"""
    # His bins
    edges = 10 ** np.arange(17, 22.51, 0.1)
    # His data values
    cddf = np.array(
        [
            858492,
            747955,
            658685,
            582018,
            518006,
            468662,
            431614,
            406575,
            387631,
            374532,
            359789,
            350348,
            342146,
            334534,
            329178,
            324411,
            320648,
            318207,
            316232,
            314852,
            314504,
            314583,
            313942,
            315802,
            316330,
            316884,
            317336,
            317979,
            316526,
            317212,
            314774,
            309333,
            302340,
            291816,
            275818,
            254368,
            228520,
            198641,
            167671,
            135412,
            103583,
            76751,
            54326,
            37745,
            25140,
            16784,
            10938,
            6740,
            3667,
            1614,
            637,
            206,
            33,
            14,
            7,
        ]
    )
    center = np.array(
        [(edges[i] + edges[i + 1]) / 2.0 for i in range(0, np.size(edges) - 1)]
    )
    width = np.array([edges[i + 1] - edges[i] for i in range(0, np.size(edges) - 1)])
    # Grid size (in cm^2)
    dX = absorption_distance()
    tot_cells = 16384**2
    cddf = (cddf) / (width * dX * tot_cells)
    plt.loglog(center, cddf, label=label)


def altay_data_moment(label="Altay 2011"):
    """Plot the simulation cddf from Altay 2011: 1012.4014"""
    # His bins
    edges = 10 ** np.arange(17, 22.51, 0.1)
    # His data values
    cddf = np.array(
        [
            858492,
            747955,
            658685,
            582018,
            518006,
            468662,
            431614,
            406575,
            387631,
            374532,
            359789,
            350348,
            342146,
            334534,
            329178,
            324411,
            320648,
            318207,
            316232,
            314852,
            314504,
            314583,
            313942,
            315802,
            316330,
            316884,
            317336,
            317979,
            316526,
            317212,
            314774,
            309333,
            302340,
            291816,
            275818,
            254368,
            228520,
            198641,
            167671,
            135412,
            103583,
            76751,
            54326,
            37745,
            25140,
            16784,
            10938,
            6740,
            3667,
            1614,
            637,
            206,
            33,
            14,
            7,
        ]
    )
    center = np.array(
        [(edges[i] + edges[i + 1]) / 2.0 for i in range(0, np.size(edges) - 1)]
    )
    width = np.array([edges[i + 1] - edges[i] for i in range(0, np.size(edges) - 1)])
    # Grid size (in cm^2)
    dX = absorption_distance()
    tot_cells = 16384**2
    cddf = (cddf) / (width * dX * tot_cells)
    plt.loglog(center, cddf * center, label=label)


def prochaska_10_data(moment=False, label="Prochaska 2010"):
    """Plot the LLS only data of Prochaska 2010, given as a box rather than the more conventional error bars.
    This is at z=3.7"""
    data = np.loadtxt(path.join(datadir, "prochaska_lls.dat"))
    ax = plt.gca()
    cddf = data[:, 1]
    if moment:
        cddf += data[:, 0]
    ax.fill(10.0 ** data[:, 0], 10.0**cddf, "grey", label=label)


def zafar_data(moment=False, label="Zafar 2013"):
    """Plot Zafar & Peroux data on LLS at z=1.5 - 5.
    This is 1307.0602.
    Format: x, y, xerr, yerr (in logspace)"""
    data = np.loadtxt(path.join(datadir, "zafar_2013.txt"))
    # Madness to put log errors into non-log
    NHI = 10 ** data[:, 0]
    cddf = 10 ** data[:, 2]
    uxer = 10 ** (data[:, 1] + data[:, 0]) - 10 ** data[:, 0]
    lxer = -(10 ** (-data[:, 1] + data[:, 0])) + 10 ** data[:, 0]
    uyer = 10 ** (data[:, 3] + data[:, 2]) - 10 ** data[:, 2]
    lyer = -(10 ** (-data[:, 4] + data[:, 2])) + 10 ** data[:, 2]
    if moment:
        lyer *= NHI
        uyer *= NHI
        cddf *= NHI
    plt.errorbar(
        NHI,
        cddf,
        xerr=[lxer, uxer],
        yerr=[lyer, uyer],
        fmt="o",
        color="grey",
        ms=5,
        label=label,
    )


def ho21_cddf(redshift=-1, moment=False, onesigma=False, label="Ho21"):
    """Plot the CDDF from https://arxiv.org/abs/2103.10964
    moment: if true plot Nf(N)
    onesigma: if true plot 68% confidence. If false plot 95% confidence"""
    if redshift < 0:
        cfile = "ho21/cddf_all.txt"
    elif 2 <= redshift < 2.5:
        cfile = "ho21/cddf_z225.txt"
    elif 2.5 <= redshift < 3:
        cfile = "ho21/cddf_z253.txt"
    elif 3 <= redshift < 4:
        cfile = "ho21/cddf_z253.txt"
    elif 4 <= redshift < 5:
        cfile = "ho21/cddf_z45.txt"
    else:
        raise ValueError("No CDDF at redshift %.2g", redshift)
    data = np.loadtxt(path.join(datadir, cfile)).T
    NHI = 10 ** data[:, 0]
    cddf = data[:, 1]
    if onesigma:
        lyer = data[:, 2]
        uyer = data[:, 3]
    else:
        lyer = data[:, 4]
        uyer = data[:, 5]
    if moment:
        lyer *= NHI
        uyer *= NHI
        cddf *= NHI
    plt.errorbar(
        NHI,
        cddf,
        yerr=[cddf - lyer, uyer - cddf],
        fmt="o",
        color="black",
        ms=5,
        label=label,
    )
    plt.yscale("log")
    plt.xscale("log")

import numpy as np
from scipy.interpolate import PchipInterpolator

# From Table 2 (Results for Spline Model — Figure 7)
logN_nodes = np.array([12.0, 15.0, 17.0, 18.0, 
                       20.0, 21.0, 21.5, 22.0])
logf_nodes = np.array([-9.72, -14.41, -17.94, -19.39,
                       -21.28, -22.82, -23.95, -25.50])

# Paper specifies cubic Hermite spline (Fritsch & Carlson 1980)
cddf_spline = PchipInterpolator(logN_nodes, logf_nodes)

def log10_f_cddf(logN):
    """
    CDDF used in Figure 7 of Prochaska et al. 2014.
    A cubic Hermite spline defined by Table 2 (Spline Model).
    """
    logN = np.asarray(logN)
    logN_clip = np.clip(logN, logN_nodes[0], logN_nodes[-1])
    return cddf_spline(logN_clip)

def f_cddf(logN):
    return 10**log10_f_cddf(logN)

# plot the CDDF from Prochaska et al. 2014
# logN_plot = np.linspace(12.0, 22.0, 500)
# plt.plot(logN_plot, f_cddf(logN_plot), label="Prochaska et al. 2014 CDDF")
# plt.yscale("log")
# plt.xlabel(r"$\log_{10} N_{\mathrm{HI}}$ [cm$^{-2}$]")
# plt.ylabel(r"$f(N_{\mathrm{HI}})$ [cm$^{2}$]")
# plt.title("Column Density Distribution Function (CDDF)")
# plt.legend()

# %% [markdown]
# My London Mock runs

# %%
### London mock : CDDF prior is from Prochaska et al. 2014
############## DLA run ################
### Somehow SNR > 6 is less biased than SNR > 8
# subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_london_cddf_nhi172_20260107/desi_snr6.0_zqsos_2.15-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_19.0-20.3/"
# SNR > 8 run
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_london_cddf_nhi172_20260107/desi_snr6.0_zqsos_3.5-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_17.2-19.0_z_dla_cddf_min_3.0_z_dla_dndx_min_3.0"
# Load Cddf
cddf_mock = np.loadtxt(os.path.join(subdir, "cddf_all.txt"))
(_, N) = cddf_mock.shape

cddf68_mock = np.full((N, 2), fill_value=np.nan)
cddf95_mock = np.full((N, 2), fill_value=np.nan)
(l_N, cddf, cddf68_mock[:, 0], cddf68_mock[:, 1], cddf95_mock[:, 0], cddf95_mock[:, 1]) = cddf_mock


# completeness correction function for the London mock CDDF
# by comparing with the true CDDF from the mock catalog, Prochaska et al. 2014 prior
def completeness_correction(logN, f_meas_mock):
    """
    Correction function.
    Assume your fiducial is the high-SNR real measurement (SNR>6), 
    and you apply a mock-based multiplicative correction per N_{\rm HI} bin:
    f^{\rm corr}_i = r_i\, f^{\rm real}_i,\qquad r_i \equiv \frac{f^{\rm true,mock}_i}{f^{\rm meas,mock}_i}.

    Parameters
    ----------
    logN : array-like
        log10 of column density N_HI [cm^-2]
    f_meas_mock : array-like
        Measured CDDF from the mock data at logN
    """
    logN = np.asarray(logN)
    f_true_mock = f_cddf(logN)
    return f_true_mock / f_meas_mock

r_mock = completeness_correction(l_N, cddf)
cddf_corrected = r_mock * cddf
cddf68_mock_corrected = np.column_stack([
    r_mock * cddf68_mock[:, 0],
    r_mock * cddf68_mock[:, 1],
])
cddf95_mock_corrected = np.column_stack([
    r_mock * cddf95_mock[:, 0],
    r_mock * cddf95_mock[:, 1],
])

# save for later
_cddf_mock = cddf

# Prochaska Spline Prior 
logN_plot = np.linspace(17.2, 22.0, 500)
plt.plot(10**logN_plot, f_cddf(logN_plot), label="Prochaska et al. 2014 CDDF", color='black')
# raw CDDF
plt.errorbar(10.0 ** l_N, cddf, yerr=[cddf - cddf68_mock[:, 0], cddf68_mock[:, 1] - cddf], fmt="o", color='C0', ms=5, label="DESI GP London Mock CDDF")
plt.fill_between(10.0 ** l_N, cddf95_mock[:, 0], cddf95_mock[:, 1], color='C0', alpha=0.3, label="DESI GP London Mock CDDF 95\%")
# completeness-corrected CDDF
plt.errorbar(10.0 ** l_N, cddf_corrected, yerr=[cddf_corrected - cddf68_mock_corrected[:, 0], cddf68_mock_corrected[:, 1] - cddf_corrected], fmt="o", color='C1', ms=5, label="Corrected DESI GP London Mock CDDF")
plt.fill_between(10.0 ** l_N, cddf95_mock_corrected[:, 0], cddf95_mock_corrected[:, 1], color='C1', alpha=0.3, label="Corrected DESI GP London Mock CDDF 95\%") 
plt.yscale("log")
plt.xscale("log")
plt.xlabel(r"$N_{\mathrm{HI}}$ [cm$^{-2}$]")
plt.ylabel(r"$f(N_{\mathrm{HI}})$ [cm$^{2}$]")
plt.title("Column Density Distribution Function (CDDF) - London Mock")
# Out:
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1575090398.py:34: RuntimeWarning: divide by zero encountered in divide
#   return f_true_mock / f_meas_mock
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1575090398.py:37: RuntimeWarning: invalid value encountered in multiply
#   cddf_corrected = r_mock * cddf
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1575090398.py:39: RuntimeWarning: invalid value encountered in multiply
#   r_mock * cddf68_mock[:, 0],
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1575090398.py:43: RuntimeWarning: invalid value encountered in multiply
#   r_mock * cddf95_mock[:, 0],
# Text(0.5, 1.0, 'Column Density Distribution Function (CDDF) - London Mock')

# %%
# the correction function
# count the variance in log space
sigma68_correction = np.diff(np.log10(cddf68_mock)) / 2.0
sigma95_correction = np.diff(np.log10(cddf95_mock)) / 2.0


plt.errorbar(10**l_N, completeness_correction(l_N, cddf), 
    yerr=[completeness_correction(l_N, cddf) - 10**(np.log10(completeness_correction(l_N, cddf)) - sigma68_correction[:, 0]),
           10**(np.log10(completeness_correction(l_N, cddf)) + sigma68_correction[:, 0]) - completeness_correction(l_N, cddf)],
    fmt="o",
    label="Correction Function", color='red', linestyle='--')
plt.fill_between(
    10**l_N,
    10**(np.log10(completeness_correction(l_N, cddf)) - sigma95_correction[:, 0]),
    10**(np.log10(completeness_correction(l_N, cddf)) + sigma95_correction[:, 0]),
    color='red', alpha=0.3
)
plt.xlabel(r"$N_{\mathrm{HI}}$ [cm$^{-2}$]")
plt.ylabel(r"Correction Factor")
plt.title("Completeness Correction Function - London Mock")
plt.legend()

plt.yscale("log")
plt.xscale("log")
# Out:
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/3727038419.py:3: RuntimeWarning: divide by zero encountered in log10
#   sigma68_correction = np.diff(np.log10(cddf68_mock)) / 2.0
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/3727038419.py:4: RuntimeWarning: divide by zero encountered in log10
#   sigma95_correction = np.diff(np.log10(cddf95_mock)) / 2.0
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1575090398.py:34: RuntimeWarning: divide by zero encountered in divide
#   return f_true_mock / f_meas_mock
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/3727038419.py:8: RuntimeWarning: invalid value encountered in subtract
#   yerr=[completeness_correction(l_N, cddf) - 10**(np.log10(completeness_correction(l_N, cddf)) - sigma68_correction[:, 0]),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/3727038419.py:9: RuntimeWarning: invalid value encountered in subtract
#   10**(np.log10(completeness_correction(l_N, cddf)) + sigma68_correction[:, 0]) - completeness_correction(l_N, cddf)],
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/3727038419.py:14: RuntimeWarning: invalid value encountered in subtract
#   10**(np.log10(completeness_correction(l_N, cddf)) - sigma95_correction[:, 0]),

# %% [markdown]
# My DESI DLA runs

# %%
############## DLA run ################
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/dla_cddf/dla_cddf_20250302/desi_snr4.0_zqsos_2.5-6.0_dla_5.5_occam_1.0_dla_model_3_subdla_lowzcut_zminlyb_highnhi_21.5_minobswave_3700.0_bins_3/"
# high_snrsubdir = "../dla_cddf/dla_cddf_20250302/desi_snr6.0_zqsos_2.5-6.0_dla_5.5_occam_1.0_dla_model_3_subdla_lowzcut_zminlyb_highnhi_21.5_minobswave_3700.0_bins_3/"
outfile = "../cddf_all/"

# Load Cddf
cddf_all = np.loadtxt(os.path.join(subdir, "cddf_all.txt"))
(_, N) = cddf_all.shape

cddf68 = np.full((N, 2), fill_value=np.nan)
cddf95 = np.full((N, 2), fill_value=np.nan)
(l_N, cddf, cddf68[:, 0], cddf68[:, 1], cddf95[:, 0], cddf95[:, 1]) = cddf_all

############### LLS run ################
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_cddf_20260107/desi_snr6.0_zqsos_3.5-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_17.2-19.0_z_dla_cddf_min_3.0_z_dla_dndx_min_3.0/"
# load Cddf
cddf_all = np.loadtxt(os.path.join(subdir, "cddf_all.txt"))
(_, N) = cddf_all.shape

cddf68_lls = np.full((N, 2), fill_value=np.nan)
cddf95_lls = np.full((N, 2), fill_value=np.nan)
(l_N_lls, cddf_lls, cddf68_lls[:, 0], cddf68_lls[:, 1], cddf95_lls[:, 0], cddf95_lls[:, 1]) = cddf_all

###### z = 4-5 LLS run ################
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_cddf_20260107/desi_snr8.0_zqsos_2.15-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_19.0-20.3/"
# load Cddf
cddf_all = np.loadtxt(os.path.join(subdir, "cddf_z45.txt"))
(_, N) = cddf_all.shape
cddf68_lls_z45 = np.full((N, 2), fill_value=np.nan)
cddf95_lls_z45 = np.full((N, 2), fill_value=np.nan)
(l_N_lls_z45, cddf_lls_z45, cddf68_lls_z45[:, 0], cddf68_lls_z45[:, 1], cddf95_lls_z45[:, 0], cddf95_lls_z45[:, 1]) = cddf_all

# %%
# Plot the CDDF
# ho21_cddf(moment=False, label="Ho (2021): eBOSS DR16, $z=2-5$")

# DESI Y3 DLA
nhi = 10**l_N
plt.errorbar(
    nhi,
    cddf,
    yerr=[cddf - cddf68[:, 0], cddf68[:, 1] - cddf],
    fmt="o",
    color=c_skyline,
    ms=5,
    label="DESI GP-DLA (raw, $z = 2-5$)",
)
plt.fill_between(
    nhi,
    cddf95[:, 0],
    cddf95[:, 1],
    color=c_skyline,
    alpha=0.2,
)
# LLS from DESI Y3
ind = l_N_lls < 20.3  # only plot up to 10^20.3 cm^-2
nhi_lls = 10**l_N_lls
plt.errorbar(
    nhi_lls[ind],
    cddf_lls[ind],
    yerr=[cddf_lls[ind] - cddf68_lls[ind, 0], cddf68_lls[ind, 1] - cddf_lls[ind]],
    fmt="o",
    color=c_flatirons,
    ms=5,
    label="DESI GP-LLS (raw, $z = 3-5$)",
)
plt.fill_between(
    nhi_lls[ind],
    cddf95_lls[ind, 0],
    cddf95_lls[ind, 1],
    color=c_flatirons,
    alpha=0.2,
)
####### Completeness-corrected LLS from DESI Y3 ##########
cddf_lls_corrected = r_mock * cddf_lls
cddf68_lls_corrected = np.column_stack([
    r_mock * cddf68_lls[:, 0],
    r_mock * cddf68_lls[:, 1],
])
cddf95_lls_corrected = np.column_stack([
    r_mock * cddf95_lls[:, 0],
    r_mock * cddf95_lls[:, 1],
])
# Add the variance from the correction function (which is the mock's variance) to the errors
cddf68_lls_corrected_err = np.column_stack([
    10**(np.log10(cddf68_lls_corrected[:, 0]) - (np.abs(np.log10(cddf68_mock[:, 0]) - np.log10(_cddf_mock)))),
    10**(np.log10(cddf68_lls_corrected[:, 1]) + (np.abs(np.log10(cddf68_mock[:, 1]) - np.log10(_cddf_mock)))),
])
cddf95_lls_corrected_err = np.column_stack([
    10**(np.log10(cddf95_lls_corrected[:, 0]) - (np.abs(np.log10(cddf95_mock[:, 0]) - np.log10(_cddf_mock)))),
    10**(np.log10(cddf95_lls_corrected[:, 1]) + (np.abs(np.log10(cddf95_mock[:, 1]) - np.log10(_cddf_mock)))),
])

plt.errorbar(
    nhi_lls[ind],
    cddf_lls_corrected[ind],
    yerr=[cddf_lls_corrected[ind] - cddf68_lls_corrected_err[ind, 0], cddf68_lls_corrected_err[ind, 1] - cddf_lls_corrected[ind]],
    fmt="o",
    color=c_midnight,
    ms=5,
    label="DESI GP-LLS (completeness corrected, $z = 3-5$)",
)
plt.fill_between(
    nhi_lls[ind],
    cddf95_lls_corrected_err[ind, 0],
    cddf95_lls_corrected_err[ind, 1],
    color=c_midnight,
    alpha=0.2,
)

# # LLS from DESI Y3 at z=4-5
# nhi_lls_z45 = 10**l_N_lls_z45
# plt.errorbar(
#     nhi_lls_z45,
#     cddf_lls_z45,
#     yerr=[cddf_lls_z45 - cddf68_lls_z45[:, 0], cddf68_lls_z45[:, 1] - cddf_lls_z45],
#     fmt="o",
#     color=c_sunshine,
#     ms=5,
#     label="DESI GP-LLS (preliminary, $z=4-5$)",
# )
# plt.fill_between(
#     nhi_lls_z45,
#     cddf95_lls_z45[:, 0],
#     cddf95_lls_z45[:, 1],
#     color=c_sunshine,
#     alpha=0.2,
# )

# altay_data(label="Altay (2011): OWLS, $z=3$")
zafar_data(moment=False, label="Zafar (2013): UVES, $z=1.5-5$")
prochaska_10_data(moment=False, label="Prochaska (2010): SDSS DR7, $z=3.7$")


# Load the CDDF from PRIYA
import glob

# # z= 2.2
# all_files = glob.glob("/Users/jibanmac/Documents/GitHub/lya_emu_xq100/priya_cddf/*-2.2.txt")
# cddf_data = []
# nhi_bins = []
# for f in all_files:
#     nhi_bins.append(np.loadtxt(f)[0])
#     cddf_data.append(np.loadtxt(f)[1])
# z = 3.0
all_files_3 = glob.glob("/Users/jibanmac/Documents/GitHub/lya_emu_xq100/priya_cddf/*-3.0.txt")
cddf_data_3 = []
nhi_bins_3 = []
for f in all_files_3:
    nhi_bins_3.append(np.loadtxt(f)[0])
    cddf_data_3.append(np.loadtxt(f)[1])
# # z = 4.0
# all_files_4 = glob.glob("/Users/jibanmac/Documents/GitHub/lya_emu_xq100/priya_cddf/*-4.0.txt")
# cddf_data_4 = []
# nhi_bins_4 = []
# for f in all_files_4:
#     nhi_bins_4.append(np.loadtxt(f)[0])
#     cddf_data_4.append(np.loadtxt(f)[1])
# Convert to numpy arrays
# nhi_bins = np.array(nhi_bins)
# cddf_data = np.array(cddf_data)
# nhi_bins_3 = np.array(nhi_bins_3)
# cddf_data_3 = np.array(cddf_data_3)
# nhi_bins_4 = np.array(nhi_bins_4)
# cddf_data_4 = np.array(cddf_data_4)

# Plot the mean CDDF over 3 sims
# plt.plot(
#     nhi_bins[0],
#     cddf_data[:].mean(axis=0) * nhi_bins[0],
#     color=matplotlib.cm.plasma(0.8),
#     label=r"PRIYA (2023): $\langle f(N)N \rangle$, $z=2.2$",
# )
# plt.plot(
#     nhi_bins_3[0],
#     cddf_data_3[:].mean(axis=0),
#     color=matplotlib.cm.plasma(0.6),
#     label=r"PRIYA (2023): $\langle f(N) \rangle$, $z=3.0$",
# )
# plt.plot(
#     nhi_bins_4[0],
#     cddf_data_4[:].mean(axis=0) * nhi_bins_4[0],
#     color=matplotlib.cm.plasma(0.4),
#     label=r"PRIYA (2023): $\langle f(N)N \rangle$, $z=4.0$",
# )
# # Plot variations over 3 sims
# for i in range(len(cddf_data)):
#     plt.plot(
#         nhi_bins_3[i],
#         cddf_data_3[i] * nhi_bins_3[i],
#         color= matplotlib.cm.plasma(0.6),
#         alpha=0.5,
#         # label="PRIYA (2023)",
#     )

# Prochaska et al. 2014 CDDF
logN_plot = np.linspace(17.2, 22.0, 500)
plt.loglog(10**logN_plot, f_cddf(logN_plot), label="Prochaska 2014 (Spline)", color="grey", linestyle="--")

plt.xlabel("$N_\mathrm{HI}$ [cm$^{-2}$]")
plt.ylabel("$f(N_\mathrm{HI})$")
plt.legend(
    loc="lower left",
    fontsize=14,
    frameon=False,
    # ncol=2,
    handlelength=1.5,
    handletextpad=0.5,
)
# plt.ylim(1e-5, 3e-1)
plt.xlim(1e17, 1e22)

plt.savefig(
    os.path.join(outfile, "gp_desi_cddf.png"),
    bbox_inches="tight",
    dpi=300,
    # fontsize=16,
    transparent=True,
    pad_inches=0.1,
    facecolor="white",
    edgecolor="none",
)
# Out:
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:53: RuntimeWarning: divide by zero encountered in log10
#   10**(np.log10(cddf68_lls_corrected[:, 0]) - (np.abs(np.log10(cddf68_mock[:, 0]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:53: RuntimeWarning: invalid value encountered in subtract
#   10**(np.log10(cddf68_lls_corrected[:, 0]) - (np.abs(np.log10(cddf68_mock[:, 0]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:54: RuntimeWarning: divide by zero encountered in log10
#   10**(np.log10(cddf68_lls_corrected[:, 1]) + (np.abs(np.log10(cddf68_mock[:, 1]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:57: RuntimeWarning: divide by zero encountered in log10
#   10**(np.log10(cddf95_lls_corrected[:, 0]) - (np.abs(np.log10(cddf95_mock[:, 0]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:57: RuntimeWarning: invalid value encountered in subtract
#   10**(np.log10(cddf95_lls_corrected[:, 0]) - (np.abs(np.log10(cddf95_mock[:, 0]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:58: RuntimeWarning: divide by zero encountered in log10
#   10**(np.log10(cddf95_lls_corrected[:, 1]) + (np.abs(np.log10(cddf95_mock[:, 1]) - np.log10(_cddf_mock)))),
# /var/folders/sn/b7hd1bmd569cjwgmtww4mv440000gn/T/ipykernel_73603/1122877645.py:64: RuntimeWarning: invalid value encountered in subtract
#   yerr=[cddf_lls_corrected[ind] - cddf68_lls_corrected_err[ind, 0], cddf68_lls_corrected_err[ind, 1] - cddf_lls_corrected[ind]],

# %% [markdown]
# ## OmegaNHI

# %% [markdown]
# subDLA (compare with Zafar 13 and Berg XQ100 2019)

# %%
def plot_omega_dla(
    z_cent: np.ndarray,
    omega_dla: np.ndarray,
    omega_dla_68: np.ndarray,
    omega_dla_95: np.ndarray,
    zmin: float = 2.0,
    zmax: float = 5.5,
    label: str = "GP",
    color: str = "blue",
    twosigma: bool = True,
    bins_per_z: int = 6,
    ylabel: str = r"$10^3 \times \Omega_\mathrm{subDLA}$",
):
    """Plot omega_DLA as a function of redshift, with full Bayesian errors"""
    nbins = np.max([int((zmax - zmin) * bins_per_z), 1])
    z_bins = np.linspace(zmin, zmax, nbins + 1)

    try:
        # hope this line works
        xerrs = (z_cent - z_bins[:-1], z_bins[1:] - z_cent)
    except ValueError as e:
        xerrs = (z_cent - z_bins[:-2], z_bins[1:-1] - z_cent)

    # import pdb
    # pdb.set_trace()

    if twosigma:
        plt.fill_between(
            z_cent,
            1000 * omega_dla_95[:, 0],
            1000 * omega_dla_95[:, 1],
            color="grey",
            alpha=0.5,
        )
    yerr = (
        omega_dla - 1000 * omega_dla_68[:, 0],
        1000 * omega_dla_68[:, 1] - omega_dla,
    )
    plt.errorbar(
        z_cent, omega_dla, yerr=yerr, xerr=xerrs, fmt="s", label=label, color=color
    )
    plt.xlabel(r"z")
    plt.ylabel(ylabel)
    plt.xlim(zmin, zmax)

# %%
# dla_data.xq100_omega(scaling=1000.0, subdla=True, label="Berg19 XQ100 ")

import pandas as pd

df = pd.read_csv("../../DLA_data/omega_hi_tableB4_metal_selected_sample.csv")

z = df["z"].values

# subDLAs
sub_med = df["OmegaHI_sub_med"].values * 1000.0
sub_lo  = df["OmegaHI_sub_p17"].values * 1000.0
sub_hi  = df["OmegaHI_sub_p83"].values * 1000.0

plt.plot(z, sub_med, label="Berg (2019) XQ100 (Metal-Selected)", color="C0")
plt.fill_between(z, sub_lo, sub_hi, alpha=0.3, color="C0")


# Zafar et al. 2013
dtype = [
    ("z_min", float),
    ("z_max", float),
    ("z_mean_DLA", float),
    ("dz_DLA", float),
    ("dX_DLA", float),
    ("Omega_DLA_1e3", float),
    ("Omega_DLA_err_1e3", float),
    ("N_DLA", int),
    ("z_mean_sub", float),
    ("dz_sub", float),
    ("dX_sub", float),
    ("Omega_sub_1e3", float),
    ("Omega_sub_err_1e3", float),
    ("N_sub", int),
    ("Omega_g_total_1e3", float),
    ("Omega_g_err_1e3", float),
    ("rho_g_1e8", float),
    ("rho_g_err_1e8", float),
]

table = np.array([
    (1.51, 2.00, 1.84, 95.6, 279.4, 0.83, 0.24, 21, 1.80, 29.9,  87.3, 0.07, 0.03,  4, 0.90, 0.20, 1.23, 0.33),
    (2.00, 2.50, 2.27,125.1, 396.6, 0.90, 0.28, 26, 2.26, 49.2, 156.8, 0.09, 0.03, 11, 0.99, 0.29, 1.35, 0.38),
    (2.50, 3.00, 2.73, 87.2, 301.0, 0.96, 0.28, 18, 2.76, 47.1, 162.8, 0.17, 0.04, 24, 1.13, 0.28, 1.54, 0.38),
    (3.00, 3.50, 3.25, 64.8, 239.6, 1.00, 0.28, 18, 3.21, 33.7, 124.5, 0.16, 0.05, 23, 1.16, 0.29, 1.58, 0.39),
    (3.50, 4.00, 3.77, 49.5, 194.6, 0.75, 0.21, 19, 3.72, 23.3,  91.7, 0.18, 0.05, 19, 1.03, 0.21, 1.40, 0.29),
    (4.00, 5.00, 4.20, 23.2,  95.6, 0.76, 0.25, 10, 4.18,  9.9,  41.0, 0.20, 0.09,  8, 0.96, 0.25, 1.31, 0.36),
], dtype=dtype)

# x-axis: mean redshift of sub-DLAs
z = table["z_mean_sub"]
# x-error: half bin width
xerr = 0.5 * (table["z_max"] - table["z_min"])
# y-axis: Omega_sub-DLA
omega = table["Omega_sub_1e3"]
omega_err = table["Omega_sub_err_1e3"]

plt.errorbar(
    z, omega,
    xerr=xerr,
    yerr=omega_err,
    fmt="o",
    capsize=3,
    label="Zafar (2013): UVES, $z=1.5-5$",
    color="black",
)

# OmegaDLA: Fiducial
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_cddf_20260107/desi_snr6.0_zqsos_2.15-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_19.0-20.3/"
omega_dla_all = np.loadtxt(os.path.join(subdir, "omega_dla_all.txt"))
(_, N) = omega_dla_all.shape

omega_dla_68 = np.full((N, 2), fill_value=np.nan)
omega_dla_95 = np.full((N, 2), fill_value=np.nan)
(
    z_cent,
    omega_dla,
    omega_dla_68[:, 0],
    omega_dla_68[:, 1],
    omega_dla_95[:, 0],
    omega_dla_95[:, 1],
) = omega_dla_all

plot_omega_dla(z_cent, omega_dla, omega_dla_68, omega_dla_95, color=c_skyline, label="DESI GP-subDLA (SNR $>$ 6)", bins_per_z=5, zmin=2, zmax=4.25)

## preserve to calc the sigma_snr effect
_omega_dla_lsnr = omega_dla
_omega_dla_68_lsnr = omega_dla_68
_omega_dla_95_lsnr = omega_dla_95

# OmegaDLA: Low-z cut
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_cddf_20260107/desi_snr8.0_zqsos_2.15-5.0_dla_5.5_occam_1.0_dla_model_1_lowzcut_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_19.0-20.3/"
omega_dla_all = np.loadtxt(os.path.join(subdir, "omega_dla_all.txt"))
(_, N) = omega_dla_all.shape

omega_dla_68 = np.full((N, 2), fill_value=np.nan)
omega_dla_95 = np.full((N, 2), fill_value=np.nan)
(
    z_cent,
    omega_dla,
    omega_dla_68[:, 0],
    omega_dla_68[:, 1],
    omega_dla_95[:, 0],
    omega_dla_95[:, 1],
) = omega_dla_all

# plot_omega_dla(z_cent, omega_dla, omega_dla_68, omega_dla_95, color=c_flatirons, label="DESI GP (SNR $>$ 8, proximity cut)", bins_per_z=5, zmin=2, zmax=4.25)
# preserve to calc the sigma_snr effect
_omega_dla_lsnr_lowzcut = omega_dla
_omega_dla_68_lsnr_lowzcut = omega_dla_68
_omega_dla_95_lsnr_lowzcut = omega_dla_95

# OmegaDLA: High SNR
subdir = "/Users/jibanmac/Documents/GitHub/desi_gpy_dla_detection_public/cddf_all/dla_cddf_20260107/desi_snr8.0_zqsos_2.15-5.0_dla_5.5_occam_1.0_dla_model_1_zminlyb_22.0_minobswave_3700.0_bins_5_lnhi_17.2-22.0_lnhi_dndx_19.0-20.3/"
omega_dla_all = np.loadtxt(os.path.join(subdir, "omega_dla_all.txt"))
(_, N) = omega_dla_all.shape

omega_dla_68 = np.full((N, 2), fill_value=np.nan)
omega_dla_95 = np.full((N, 2), fill_value=np.nan)
(
    z_cent,
    omega_dla,
    omega_dla_68[:, 0],
    omega_dla_68[:, 1],
    omega_dla_95[:, 0],
    omega_dla_95[:, 1],
) = omega_dla_all

# plot_omega_dla(z_cent, omega_dla, omega_dla_68, omega_dla_95, color=c_skyline, label="DESI GP (SNR $>$ 8)", bins_per_z=5, zmin=2, zmax=4.25)

####### Final plot with SNR systematic ########
## This reads as: “stat interval widened by a worst-case SNR shift.”
# conservative single “total” bound (linear add) 
delta_snr = np.abs(_omega_dla_lsnr - omega_dla) / 1000
# delta_proximity = np.abs(_omega_dla_lsnr_lowzcut - omega_dla) / 1000
# delta_snr += delta_proximity
omega_dla_68_with_snr = np.column_stack([
    omega_dla_68[:, 0] - delta_snr,   # lower bound moves down
    omega_dla_68[:, 1] + delta_snr,   # upper bound moves up
])
omega_dla_95_with_snr = np.column_stack([
    omega_dla_95[:, 0] - delta_snr,
    omega_dla_95[:, 1] + delta_snr,
])

plot_omega_dla(
    z_cent,
    omega_dla,
    omega_dla_68_with_snr,
    omega_dla_95_with_snr,
    color="purple",
    label="DESI GP-subDLA (SNR $>$ 8 + $\sigma_{sys}$)",
    bins_per_z=5,
    zmin=2,
    zmax=4.25,
)

plt.legend(
    loc="upper left",
    fontsize=14,
    frameon=False,
    # ncol=2,
    handlelength=1.5,
    handletextpad=0.5,
)

plt.savefig(
    os.path.join(outfile, "gp_desi_omegasubdla.png"),
    bbox_inches="tight",
    dpi=300,
    # fontsize=16,
    transparent=True,
    pad_inches=0.1,
    facecolor="white",
    edgecolor="none",
)
